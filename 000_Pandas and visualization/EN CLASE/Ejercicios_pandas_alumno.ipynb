# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# Cargamos el dataset diamonds:

# %%
data = seaborn.load_dataset('diamonds')

# %%
subdata=data.head(1000)

# %%
subdata.to_csv()
# Out:
# ',carat,cut,color,clarity,depth,table,price,x,y,z\n0,0.23,Ideal,E,SI2,61.5,55.0,326,3.95,3.98,2.43\n1,0.21,Premium,E,SI1,59.8,61.0,326,3.89,3.84,2.31\n2,0.23,Good,E,VS1,56.9,65.0,327,4.05,4.07,2.31\n3,0.29,Premium,I,VS2,62.4,58.0,334,4.2,4.23,2.63\n4,0.31,Good,J,SI2,63.3,58.0,335,4.34,4.35,2.75\n5,0.24,Very Good,J,VVS2,62.8,57.0,336,3.94,3.96,2.48\n6,0.24,Very Good,I,VVS1,62.3,57.0,336,3.95,3.98,2.47\n7,0.26,Very Good,H,SI1,61.9,55.0,337,4.07,4.11,2.53\n8,0.22,Fair,E,VS2,65.1,61.0,337,3.87,3.78,2.49\n9,0.23,Very Good,H,VS1,59.4,61.0,338,4.0,4.05,2.39\n10,0.3,Good,J,SI1,64.0,55.0,339,4.25,4.28,2.73\n11,0.23,Ideal,J,VS1,62.8,56.0,340,3.93,3.9,2.46\n12,0.22,Premium,F,SI1,60.4,61.0,342,3.88,3.84,2.33\n13,0.31,Ideal,J,SI2,62.2,54.0,344,4.35,4.37,2.71\n14,0.2,Premium,E,SI2,60.2,62.0,345,3.79,3.75,2.27\n15,0.32,Premium,E,I1,60.9,58.0,345,4.38,4.42,2.68\n16,0.3,Ideal,I,SI2,62.0,54.0,348,4.31,4.34,2.68\n17,0.3,Good,J,SI1,63.4,54.0,351,4.23,4.29,2.7\n18,0.3,Good,J,SI1,63.8,56.0,351,4.23,4.26,2.71\n19,0.3,Very Good,J,SI1,62.7,59.0,351,4.21,4.27,2.66\n20,0.3,Good,I,SI2,63.3,56.0,351,4.26,4.3,2.71\n21,0.23,Very Good,E,VS2,63.8,55.0,352,3.85,3.92,2.48\n22,0.23,Very Good,H,VS1,61.0,57.0,353,3.94,3.96,2.41\n23,0.31,Very Good,J,SI1,59.4,62.0,353,4.39,4.43,2.62\n24,0.31,Very Good,J,SI1,58.1,62.0,353,4.44,4.47,2.59\n25,0.23,Very Good,G,VVS2,60.4,58.0,354,3.97,4.01,2.41\n26,0.24,Premium,I,VS1,62.5,57.0,355,3.97,3.94,2.47\n27,0.3,Very Good,J,VS2,62.2,57.0,357,4.28,4.3,2.67\n28,0.23,Very Good,D,VS2,60.5,61.0,357,3.96,3.97,2.4\n29,0.23,Very Good,F,VS1,60.9,57.0,357,3.96,3.99,2.42\n30,0.23,Very Good,F,VS1,60.0,57.0,402,4.0,4.03,2.41\n31,0.23,Very Good,F,VS1,59.8,57.0,402,4.04,4.06,2.42\n32,0.23,Very Good,E,VS1,60.7,59.0,402,3.97,4.01,2.42\n33,0.23,Very Good,E,VS1,59.5,58.0,402,4.01,4.06,2.4\n34,0.23,Very Good,D,VS1,61.9,58.0,402,3.92,3.96,2.44\n35,0.23,Good,F,VS1,58.2,59.0,402,4.06,4.08,2.37\n36,0.23,Good,E,VS1,64.1,59.0,402,3.83,3.85,2.46\n37,0.31,Good,H,SI1,64.0,54.0,402,4.29,4.31,2.75\n38,0.26,Very Good,D,VS2,60.8,59.0,403,4.13,4.16,2.52\n39,0.33,Ideal,I,SI2,61.8,55.0,403,4.49,4.51,2.78\n40,0.33,Ideal,I,SI2,61.2,56.0,403,4.49,4.5,2.75\n41,0.33,Ideal,J,SI1,61.1,56.0,403,4.49,4.55,2.76\n42,0.26,Good,D,VS2,65.2,56.0,403,3.99,4.02,2.61\n43,0.26,Good,D,VS1,58.4,63.0,403,4.19,4.24,2.46\n44,0.32,Good,H,SI2,63.1,56.0,403,4.34,4.37,2.75\n45,0.29,Premium,F,SI1,62.4,58.0,403,4.24,4.26,2.65\n46,0.32,Very Good,H,SI2,61.8,55.0,403,4.35,4.42,2.71\n47,0.32,Good,H,SI2,63.8,56.0,403,4.36,4.38,2.79\n48,0.25,Very Good,E,VS2,63.3,60.0,404,4.0,4.03,2.54\n49,0.29,Very Good,H,SI2,60.7,60.0,404,4.33,4.37,2.64\n50,0.24,Very Good,F,SI1,60.9,61.0,404,4.02,4.03,2.45\n51,0.23,Ideal,G,VS1,61.9,54.0,404,3.93,3.95,2.44\n52,0.32,Ideal,I,SI1,60.9,55.0,404,4.45,4.48,2.72\n53,0.22,Premium,E,VS2,61.6,58.0,404,3.93,3.89,2.41\n54,0.22,Premium,D,VS2,59.3,62.0,404,3.91,3.88,2.31\n55,0.3,Ideal,I,SI2,61.0,59.0,405,4.3,4.33,2.63\n56,0.3,Premium,J,SI2,59.3,61.0,405,4.43,4.38,2.61\n57,0.3,Very Good,I,SI1,62.6,57.0,405,4.25,4.28,2.67\n58,0.3,Very Good,I,SI1,63.0,57.0,405,4.28,4.32,2.71\n59,0.3,Good,I,SI1,63.2,55.0,405,4.25,4.29,2.7\n60,0.35,Ideal,I,VS1,60.9,57.0,552,4.54,4.59,2.78\n61,0.3,Premium,D,SI1,62.6,59.0,552,4.23,4.27,2.66\n62,0.3,Ideal,D,SI1,62.5,57.0,552,4.29,4.32,2.69\n63,0.3,Ideal,D,SI1,62.1,56.0,552,4.3,4.33,2.68\n64,0.42,Premium,I,SI2,61.5,59.0,552,4.78,4.84,2.96\n65,0.28,Ideal,G,VVS2,61.4,56.0,553,4.19,4.22,2.58\n66,0.32,Ideal,I,VVS1,62.0,55.3,553,4.39,4.42,2.73\n67,0.31,Very Good,G,SI1,63.3,57.0,553,4.33,4.3,2.73\n68,0.31,Premium,G,SI1,61.8,58.0,553,4.35,4.32,2.68\n69,0.24,Premium,E,VVS1,60.7,58.0,553,4.01,4.03,2.44\n70,0.24,Very Good,D,VVS1,61.5,60.0,553,3.97,4.0,2.45\n71,0.3,Very Good,H,SI1,63.1,56.0,554,4.29,4.27,2.7\n72,0.3,Premium,H,SI1,62.9,59.0,554,4.28,4.24,2.68\n73,0.3,Premium,H,SI1,62.5,57.0,554,4.29,4.25,2.67\n74,0.3,Good,H,SI1,63.7,57.0,554,4.28,4.26,2.72\n75,0.26,Very Good,F,VVS2,59.2,60.0,554,4.19,4.22,2.49\n76,0.26,Very Good,E,VVS2,59.9,58.0,554,4.15,4.23,2.51\n77 ...

# %%
data[0:10]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# ## Estudio preliminar

# %% [markdown]
# 1. Haz un estudio preliminar del dataset: Tamaño, tipo de variables, estadísticos básicos.

# %%
xxx=data['x']
xxx.value_counts(bins=10)
# Out:
# (4.296, 5.37]                     20895
# (5.37, 6.444]                     14440
# (6.444, 7.518]                    12205
# (7.518, 8.592]                     3260
# (3.222, 4.296]                     2934
# (8.592, 9.666]                      191
# (-0.011699999999999999, 1.074]        8
# (9.666, 10.74]                        7
# (2.148, 3.222]                        0
# (1.074, 2.148]                        0
# Name: x, dtype: int64

# %%
len(data.columns), len(data)
# Out:
# (10, 53940)

# %%
list(data.columns.dtype())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5cfe2961e2fd> in <module>
# ----> 1 list(data.columns.dtype())
#
# TypeError: 'numpy.dtype' object is not callable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
# carat      53940 non-null float64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   53940.000000  53940  53940   53940  53940.000000  53940.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  21551  11292   13065           NaN           NaN
# mean        0.797940    NaN    NaN     NaN     61.749405     57.457184
# std         0.474011    NaN    NaN     NaN      1.432621      2.234491
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         5.010000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# count   53940.000000  53940.000000  53940.000000  53940.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean     3932.799722      5.731157      5.734526      3.538734
# std      3989.439738      1.121761      1.142135      0.705699
# min       326.000000      0.000000      0.000000      0.000000
# 25%       950.000000      4.710000      4.720000      2.910000
# 50%      2401.000000      5.700000      5.710000      3.530000
# 75%      5324.250000      6.540000      6.540000      4.040000
# max     18823.000000     10.740000     58.900000     31.800000

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
data.describe().transpose()

# %% [markdown]
# ## The grammar of data manipulation

# %% [markdown]
# ### Seleccionar

# %% [markdown]
# 2. Selecciona la columna 'price' y toma su media:

# %%
data['price'].mean()
# Out:
# 3932.799721913237

# %% [markdown]
# 3. Selecciona por posición las variables 'x' e 'y' y restalas creando una columna nueva 'dif_xy'.

# %%
data['dif_xy']=data['x']-data['y']

# %%
data.iloc[:,8]
# Out:
# 0        3.98
# 1        3.84
# 2        4.07
# 3        4.23
# 4        4.35
# 5        3.96
# 6        3.98
# 7        4.11
# 8        3.78
# 9        4.05
# 10       4.28
# 11       3.90
# 12       3.84
# 13       4.37
# 14       3.75
# 15       4.42
# 16       4.34
# 17       4.29
# 18       4.26
# 19       4.27
# 20       4.30
# 21       3.92
# 22       3.96
# 23       4.43
# 24       4.47
# 25       4.01
# 26       3.94
# 27       4.30
# 28       3.97
# 29       3.99
#          ...
# 53910    5.77
# 53911    5.38
# 53912    5.40
# 53913    5.81
# 53914    5.90
# 53915    5.86
# 53916    5.74
# 53917    6.09
# 53918    5.85
# 53919    5.87
# 53920    5.61
# 53921    5.65
# 53922    5.58
# 53923    5.84
# 53924    5.84
# 53925    5.97
# 53926    5.73
# 53927    6.13
# 53928    5.96
# 53929    5.73
# 53930    5.74
# 53931    5.73
# 53932    5.76
# 53933    5.72
# 53934    5.73
# 53935    5.76
# 53936    5.75
# 53937    5.68
# 53938    6.12
# 53939    5.87
# Name: y, Length: 53940, dtype: float64

# %%
data['dif_xy2']=data.iloc[:,8]-data.iloc[:,9]

# %%
data['dif_xy3']=data.iloc[:,-3:-1].diff(axis=1).dropna(axis=1).values

# %%
data.iloc[:,-3:-1].diff(axis=1)
# Out:
#        dif_xy  dif_xy2
# 0         NaN     1.58
# 1         NaN     1.48
# 2         NaN     1.78
# 3         NaN     1.63
# 4         NaN     1.61
# 5         NaN     1.50
# 6         NaN     1.54
# 7         NaN     1.62
# 8         NaN     1.20
# 9         NaN     1.71
# 10        NaN     1.58
# 11        NaN     1.41
# 12        NaN     1.47
# 13        NaN     1.68
# 14        NaN     1.44
# 15        NaN     1.78
# 16        NaN     1.69
# 17        NaN     1.65
# 18        NaN     1.58
# 19        NaN     1.67
# 20        NaN     1.63
# 21        NaN     1.51
# 22        NaN     1.57
# 23        NaN     1.85
# 24        NaN     1.91
# 25        NaN     1.64
# 26        NaN     1.44
# 27        NaN     1.65
# 28        NaN     1.58
# 29        NaN     1.60
# ...       ...      ...
# 53910     NaN     2.32
# 53911     NaN     2.10
# 53912     NaN     1.96
# 53913     NaN     2.04
# 53914     NaN     2.09
# 53915     NaN     2.25
# 53916     NaN     2.16
# 53917     NaN     2.20
# 53918     NaN     2.28
# 53919     NaN     2.19
# 53920     NaN     2.16
# 53921     NaN     2.18
# 53922     NaN     1.94
# 53923     NaN     2.31
# 53924     NaN     2.27
# 53925     NaN     2.32
# 53926     NaN     2.21
# 53927     NaN     2.66
# 53928     NaN     2.21
# 53929     NaN     2.17
# 53930     NaN     2.20
# 53931     NaN     2.29
# 53932     NaN     2.34
# 53933     NaN     2.26
# 53934     NaN     2.19
# 53935     NaN     2.27
# 53936     NaN     2.20
# 53937     NaN     2.14
# 53938     NaN     2.35
# 53939     NaN     2.27
#
# [53940 rows x 2 columns]

# %%
xxx=data['x']
xxx.value_counts(bins=10)

# %%
data[0:10]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#    dif_xy
# 0   -0.03
# 1    0.05
# 2   -0.02
# 3   -0.03
# 4   -0.01
# 5   -0.02
# 6   -0.03
# 7   -0.04
# 8    0.09
# 9   -0.05

# %% [markdown]
# 4. Elimina la variable que acabas de crear. Sin asignar con data = ...

# %%
data.drop('dif_xy', axis=1, inplace=True)

# %% [markdown]
# ### Filtrar

# %% [markdown]
# 5. Sólo dispongo de 1000 $ como mucho. ¿Qué tipo de diamante puedo esperar (estadísticos básicos)?

# %%
data[data['price']<=1000].describe()
# Out:
#               carat         depth         table         price             x  \
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       0.334937     61.751205     56.968246    708.384880      4.450930
# std        0.053038      1.162221      2.084667    161.849058      0.230993
# min        0.200000     51.000000     44.000000    326.000000      3.730000
# 25%        0.300000     61.200000     55.000000    579.000000      4.310000
# 50%        0.320000     61.800000     57.000000    709.000000      4.410000
# 75%        0.370000     62.400000     58.000000    842.000000      4.610000
# max        0.720000     71.000000     68.000000   1000.000000      6.650000
#
#                   y             z        dif_xy       dif_xy2       dif_xy3
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       4.463025      2.751935     -0.012095      1.711091      1.723186
# std        0.229320      0.147038      0.042217      0.107838      0.121383
# min        3.680000      2.240000     -1.510000      1.270000     -0.070000
# 25%        4.320000      2.670000     -0.040000      1.640000      1.640000
# 50%        4.420000      2.720000     -0.030000      1.700000      1.720000
# 75%        4.620000      2.840000      0.020000      1.780000      1.800000
# max        6.020000      4.440000      2.040000      2.340000      3.090000

# %%
data.loc[data['price']<=1000,:].describe()
# Out:
#               carat         depth         table         price             x  \
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       0.334937     61.751205     56.968246    708.384880      4.450930
# std        0.053038      1.162221      2.084667    161.849058      0.230993
# min        0.200000     51.000000     44.000000    326.000000      3.730000
# 25%        0.300000     61.200000     55.000000    579.000000      4.310000
# 50%        0.320000     61.800000     57.000000    709.000000      4.410000
# 75%        0.370000     62.400000     58.000000    842.000000      4.610000
# max        0.720000     71.000000     68.000000   1000.000000      6.650000
#
#                   y             z        dif_xy       dif_xy2       dif_xy3
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       4.463025      2.751935     -0.012095      1.711091      1.723186
# std        0.229320      0.147038      0.042217      0.107838      0.121383
# min        3.680000      2.240000     -1.510000      1.270000     -0.070000
# 25%        4.320000      2.670000     -0.040000      1.640000      1.640000
# 50%        4.420000      2.720000     -0.030000      1.700000      1.720000
# 75%        4.620000      2.840000      0.020000      1.780000      1.800000
# max        6.020000      4.440000      2.040000      2.340000      3.090000

# %%
data.query('price<=1000').describe()
# Out:
#               carat         depth         table         price             x  \
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       0.334937     61.751205     56.968246    708.384880      4.450930
# std        0.053038      1.162221      2.084667    161.849058      0.230993
# min        0.200000     51.000000     44.000000    326.000000      3.730000
# 25%        0.300000     61.200000     55.000000    579.000000      4.310000
# 50%        0.320000     61.800000     57.000000    709.000000      4.410000
# 75%        0.370000     62.400000     58.000000    842.000000      4.610000
# max        0.720000     71.000000     68.000000   1000.000000      6.650000
#
#                   y             z        dif_xy       dif_xy2       dif_xy3
# count  14524.000000  14524.000000  14524.000000  14524.000000  14524.000000
# mean       4.463025      2.751935     -0.012095      1.711091      1.723186
# std        0.229320      0.147038      0.042217      0.107838      0.121383
# min        3.680000      2.240000     -1.510000      1.270000     -0.070000
# 25%        4.320000      2.670000     -0.040000      1.640000      1.640000
# 50%        4.420000      2.720000     -0.030000      1.700000      1.720000
# 75%        4.620000      2.840000      0.020000      1.780000      1.800000
# max        6.020000      4.440000      2.040000      2.340000      3.090000

# %%
aaa=data['carat'].quantile(0.25)

# %%
aaa
# Out:
# 0.4

# %% [markdown]
# 6. Además, me gustaría que fuese de corte Premium y carat por encima del percentil 25 del dataset global. Muéstrame 8 cualquiera que cumplan las dos condiciones.

# %%
mi_diamante=data[(data['price']<=1000) & (data['cut']=='Premium') &(data['carat']>data['carat'].quantile(0.25))]

mi_diamante.sort_values(by=['price'], ascending=True).head(8)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 31962   0.43  Premium     H      I1   62.0   59.0    452  4.78  4.83  2.98
# 49299   0.41  Premium     I     SI2   61.6   59.0    539  4.76  4.79  2.94
# 64      0.42  Premium     I     SI2   61.5   59.0    552  4.78  4.84  2.96
# 7736    0.43  Premium     H      I1   62.0   59.0    581  4.83  4.78  2.98
# 13032   0.41  Premium     I     SI2   60.6   59.0    600  4.84  4.80  2.92
# 13738   0.41  Premium     F     SI2   59.0   58.0    604  4.87  4.89  2.88
# 16738   0.41  Premium     G     SI2   61.4   58.0    611  4.75  4.80  2.93
# 16734   0.41  Premium     J     VS2   61.9   59.0    611  4.69  4.74  2.92
#
#        dif_xy  dif_xy2  dif_xy3
# 31962   -0.05     1.85     1.90
# 49299   -0.03     1.85     1.88
# 64      -0.06     1.88     1.94
# 7736     0.05     1.80     1.75
# 13032    0.04     1.88     1.84
# 13738   -0.02     2.01     2.03
# 16738   -0.05     1.87     1.92
# 16734   -0.05     1.82     1.87

# %%
data.sample(8)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 10152   1.10      Ideal     H     SI2   63.1   58.0   4725  6.54  6.53  4.12
# 23909   1.70  Very Good     E     SI2   63.3   57.0  12030  7.59  7.51  4.78
# 25283   2.23    Premium     J     SI2   61.3   60.0  13931  8.40  8.35  5.13
# 3436    0.90    Premium     H     SI1   62.6   58.0   3387  6.12  6.08  3.82
# 37671   0.42      Ideal     E     SI1   61.3   57.0    992  4.81  4.79  2.94
# 35740   0.30    Premium     D     VS2   62.9   61.0    911  4.29  4.27  2.69
# 12606   1.23       Good     J     VS2   63.6   57.0   5290  6.74  6.79  4.30
# 41553   0.41      Ideal     F    VVS1   62.3   56.0   1236  4.79  4.77  2.98
#
#        dif_xy  dif_xy2  dif_xy3
# 10152    0.01     2.41     2.40
# 23909    0.08     2.73     2.65
# 25283    0.05     3.22     3.17
# 3436     0.04     2.26     2.22
# 37671    0.02     1.85     1.83
# 35740    0.02     1.58     1.56
# 12606   -0.05     2.49     2.54
# 41553    0.02     1.79     1.77

# %%
data.sample(frac=0.0001)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 51064   0.65  Very Good     I      IF   61.0   55.0   2332  5.65  5.73  3.47
# 294     0.74      Ideal     H     VS1   61.8   58.0   2797  5.77  5.81  3.58
# 10898   1.02    Premium     H     SI1   60.5   60.0   4884  6.58  6.51  3.96
# 46958   0.27      Ideal     H    VVS2   62.2   56.0    527  4.15  4.18  2.59
# 14299   1.08      Ideal     H     VS1   61.9   57.0   5791  6.58  6.64  4.09
#
#        dif_xy  dif_xy2  dif_xy3
# 51064   -0.08     2.26     2.34
# 294     -0.04     2.23     2.27
# 10898    0.07     2.55     2.48
# 46958   -0.03     1.59     1.62
# 14299   -0.06     2.55     2.61

# %%
carat25=np.percentile(data.carat,25)

mi_diamante=data[('price'<=1000) & ('cut'=='Premium') &('carat'>@carat25)]

mi_diamante.sort_values(by=['price'], ascending=True).head(8)

# %%
data['xyz']=data['x']*data['y']*data['z']

# %%
data['densidad']=data['carat']/data['xyz']

# %%
plt.scatter (data['xyz'],data['carat'])

# %%
data['densidad'].describe()
# Out:
# count    5.394000e+04
# mean              inf
# std               NaN
# min      5.207522e-04
# 25%      6.048258e-03
# 50%      6.117055e-03
# 75%      6.190173e-03
# max               inf
# Name: densidad, dtype: float64

# %%
plt.plot (list(range(1,len(data['densidad'])+1)), data['densidad'].sort_values())

# %% [markdown]
# 8. Crea una nueva columna que se llame cut_numeric, asigne un número siguiendo el orden de incremento de mejora del corte: Fair -> 0, etc.

# %%
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
cutnum={}

# %%
data.loc[:,'cut_numeric']=data.cut.map(dict_cutnum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-870fc9e2f65d> in <module>
# ----> 1 data.loc[:,'cut_numeric']=data.cut.map(dict_cutnum)
#
# NameError: name 'dict_cutnum' is not defined

# %% [markdown]
# 9. Calcula la diferencia entre máximo y mínimo para las variables 'x', 'y', 'z':

# %%
data.loc[:,['x','y','z']].apply(lambda x:x.max()-x.min())

# %% [markdown]
# 10. Muestra los primeros 10 diamantes con las variables numéricas redondeadas a 2 decimales:

# %%
data_tail10=data.head(10).copy()

data.round(2).head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#    dif_xy  dif_xy2  dif_xy3    xyz  densidad
# 0   -0.03     1.55     1.58  38.20      0.01
# 1    0.05     1.53     1.48  34.51      0.01
# 2   -0.02     1.76     1.78  38.08      0.01
# 3   -0.03     1.60     1.63  46.72      0.01
# 4   -0.01     1.60     1.61  51.92      0.01
# 5   -0.02     1.48     1.50  38.69      0.01
# 6   -0.03     1.51     1.54  38.83      0.01
# 7   -0.04     1.58     1.62  42.32      0.01
# 8    0.09     1.29     1.20  36.43      0.01
# 9   -0.05     1.66     1.71  38.72      0.01

# %% [markdown]
# ### Arrange

# %% [markdown]
# 11. Muestra los tres diamantes más caros.

# %% [markdown]
# 12. Muestra los 3 diamantes más baratos del peor corte:

# %% [markdown]
# ### Group by and summarise

# %% [markdown]
# 13. Agrupa por corte y muestra la media de depth y table para cada grupo. Recuerda ordenar de peor a mejor 'cut'.

# %% [markdown]
# 14. Agrupa por 'clarity' y muestra la mediana de depth y la media  y máximo de precio. Ordena por precio medio.

# %% [markdown]
# 15. Convierte en un DataFrame la tabla multiíndice anterior:

# %% [markdown]
# 16. Repite los dos ejercicios anteriores pero agrupando por 'clarity', 'color' y 'cut'; además no uses el precio sino el precio por quilate.
