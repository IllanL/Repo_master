# %%
# !pwd
# Out:
# /home/dsc/Data/opentraveldata/python_class

# %%
!  curl -s http://www.gutenberg.org/files/76/76-0.txt > Finn.txt
# !head Finn.txt
# Out:
# ﻿
# The Project Gutenberg EBook of Adventures of Huckleberry Finn, Complete
# by Mark Twain (Samuel Clemens)
#
# This eBook is for the use of anyone anywhere at no cost and with almost
# no restrictions whatsoever. You may copy it, give it away or re-use
# it under the terms of the Project Gutenberg License included with this
# eBook or online at www.gutenberg.net
#
# Title: Adventures of Huckleberry Finn, Complete

# %%
f=open('Finn.txt')

print(type(f))

print(f.read(20))
print(f.read(20))
# Out:
# <class '_io.TextIOWrapper'>
# ﻿
# The Project Gutenb
# erg EBook of Adventu

# %%
f.tell()
# Out:
# 43

# %%
f=open('Finn.txt')

print(type(f))

print(f.read(20))
print(f.read(20))
# Out:
# <class '_io.TextIOWrapper'>
# ﻿
# The Project Gutenb
# erg EBook of Adventu

# %%
# !cat -n ./Finn.txt
# Out:
#      1	﻿
#      2	The Project Gutenberg EBook of Adventures of Huckleberry Finn, Complete
#      3	by Mark Twain (Samuel Clemens)
#      4
#      5	This eBook is for the use of anyone anywhere at no cost and with almost
#      6	no restrictions whatsoever. You may copy it, give it away or re-use
#      7	it under the terms of the Project Gutenberg License included with this
#      8	eBook or online at www.gutenberg.net
#      9
#     10	Title: Adventures of Huckleberry Finn, Complete
#     11
#     12	Author: Mark Twain (Samuel Clemens)
#     13
#     14	Release Date: August 20, 2006 [EBook #76]
#     15	Last Updated: February 23, 2018
#     16	Language: English
#     17
#     18	Character set encoding: UTF-8
#     19
#     20	*** START OF THIS PROJECT GUTENBERG EBOOK HUCKLEBERRY FINN ***
#     21
#     22	Produced by David Widger
#     23
#     24
#     25
#     26
#     27
#     28	ADVENTURES
#     29
#     30	OF
#     31
#     32	HUCKLEBERRY FINN
#     33
# ...

# %%
#para ir a una posición:
f.seek(0)

print(f.tell())

f.seek(1000).read()
# Out:
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-fc146628353d> in <module>
#       4 print(f.tell())
#       5
# ----> 6 f.seek(1000).read()
#       7
#       8 f.closed
#
# AttributeError: 'int' object has no attribute 'read'

# %%
print(f.closed)

f.close
# Out:
# False
# <function TextIOWrapper.close()>

# %%
f=open('nuevo_fichero_texto.txt', 'w')

# %%
f.write=('Di_hola.txt')
a=! ls -l
print(a)
f.close
a=! ls -l
print(a)
# Out:
# ['total 1680', '-rw-rw-r-- 1 dsc dsc   11755 may 11 11:00 01_intro.ipynb', '-rw-rw-r-- 1 dsc dsc   10442 may 11 13:24 02_flow_control.ipynb', '-rw-rw-r-- 1 dsc dsc   38610 may 17 17:52 03_shell_magics.ipynb', '-rw-rw-r-- 1 dsc dsc    2714 may 17 18:30 06_EXERCISES.ipynb', '-rw-rw-r-- 1 dsc dsc 1016822 may 17 18:59 07_working_with_files.ipynb', '-rw-rw-r-- 1 dsc dsc      63 may 11 13:54 fichero_python_importar.py', '-rw-rw-r-- 1 dsc dsc  616320 may 17 18:34 Finn.txt', '-rw-rw-r-- 1 dsc dsc      29 may 17 17:10 hello.py', '-rw-rw-r-- 1 dsc dsc       0 may 17 18:59 nuevo_fichero_texto.txt', 'drwxrwxr-x 2 dsc dsc    4096 may 11 12:11 __pycache__']
# ...

# %%
a=['a','q','w','c','a','c']

# %%
len(a)
# Out:
# 6

# %%
a[2]=None

# %%
x=[]
for i in a:
    if i!='a':
        x.append(i)
    
print(x)
# Out:
# ['q', None, 'c', 'c']

# %%
x=[]
for i in a:
        x.append(i!='a')

print(x)
        
import pandas as pd
aprima=pd.DataFrame(a)
b=aprima[x]
print(b)
# Out:
# [False, True, True, True, False, True]
#    0
# 1  q
# 2  w
# 3  c
# 5  c

# %%
import pandas as pd
aprima=pd.DataFrame(a)
print(aprima!='a')
b=aprima[aprima[0]!='a']
print(b)
# Out:
#        0
# 0  False
# 1   True
# 2   True
# 3   True
# 4  False
# 5   True
#    0
# 1  q
# 2  w
# 3  c
# 5  c

# %%
a=['a','q','w','c','a','c']

# %%
b=reversed(a)
print(b)
c=list(b)
print(c)
# Out:
# ...
# ['c', 'a', 'c', 'w', 'q', 'a']

# %%
numbers=[1,10,20,22,7]
numbers.sort()
numbers
# Out:
# [1, 7, 10, 20, 22]

# %%
numbers=[1,10,20,22,7,'3',2.5]
numbers.sort(key=float)
numbers
# Out:
# [1, 2.5, '3', 7, 10, 20, 22]

# %%
numbers=[1,10,20,22,7,'3',2.5]
numbers.sort(key=str)
numbers
# Out:
# [1, 10, 2.5, 20, 22, '3', 7]

# %%
numbers=[1,10,20,22,7,'3',2.5]
numbers.sort(key=str, reverse=True)
numbers
# Out:
# [7, '3', 22, 20, 2.5, 10, 1]

# %%
numbers=[1,10,20,22,7,2.5]
sorted(numbers)
# Out:
# [1, 2.5, 7, 10, 20, 22]

# %%
a='Say hi'
sorted(a, reverse=True)
a
# Out:
# 'Say hi'

# %%
numbers=[1,10,20,22,7,'3',2.5]
numbers2=[str(x) for x in numbers]
numbers2.sort(key=len)
numbers2
# Out:
# ['1', '7', '3', '10', '20', '22', '2.5']

# %%
numbers=[1,10,20,22,7,'3',2.5]
numbers2.sort(key=str)
numbers2
# Out:
# ['1', '10', '2.5', '20', '22', '3', '7']

# %%
def upper_func(x):
    return str(x).upper()

x=['gfdsdfghgfds','trewf','trdf','sdgfgd', '3', 4, 'coche', 'perro']

x.sort(key=upper_func)
x
# Out:
# ['3', 4, 'coche', 'gfdsdfghgfds', 'perro', 'sdgfgd', 'trdf', 'trewf']

# %%
funcion_corta=lambda x:x**2

funcion_corta(5)
# Out:
# 25

# %%
x=['gfdsdfghgfds','trewf','trdf','sdgfgd', '3', 4, 'coche', 'perro']

x.sort(key=lambda x: str(x).count('t'))
x
# Out:
# ['gfdsdfghgfds', 'sdgfgd', '3', 4, 'coche', 'perro', 'trewf', 'trdf']

# %%
a=[1,2,3]

b=lambda x: x+['a']
a
b(a)
# Out:
# [1, 2, 3, 'a']

# %%
a=[1,2,3]

k3=list(map(lambda x:x+1, a))

k3
# Out:
# [2, 3, 4]

# %%
lista_entrada=[1,2,3,4,5,6,7,8]

lista_salida=[val**2 if val%2 else 0 for val in lista_entrada]
lista_salida
# Out:
# [1, 0, 9, 0, 25, 0, 49, 0]

# %%
lista_entrada=[1,2,3,4,5,6,7,8]

lista_salida=[val**2  for val in lista_entrada if val%2 ]
lista_salida
# Out:
# [1, 9, 25, 49]

# %%
algunas_tuplas=[(1,2,3),(4,5,6),(7,8,9)]

flattened_tupla=list(map(lambda x: list(map(lambda y:y, x)), algunas_tuplas))
flattened_tupla
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
algunas_tuplas=[(1,2,3),(4,5,6),(7,8,9)]

flattened_tupla=list(val for cosa in algunas_tuplas for val in cosa)
flattened_tupla
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
nombres=["Bob","Igor","Anita","Ronaldo","Messi"]

nuevos_nombres=list(cosa.lower() for cosa in nombres)
nuevos_nombres
# Out:
# ['bob', 'igor', 'anita', 'ronaldo', 'messi']

# %%
nombres=["Bob","Igor","Anita","Ronaldo","Messi"]

#nuevos_nombres=list(a=a+val.lower() if val.index==1 else a=a+val.upper() for cosa in nombres for val in cosa)

b=[]

for cosa in nombres:
    a=[]
    for val in cosa:
        if val.lower() in 'aeiou':
            a.append(val.upper())
            
        else:
            a.append(val.lower())
            
    c=''.join(a)
    
    b.append(c)
    
            
b
# Out:
# ['bOb', 'IgOr', 'AnItA', 'rOnAldO', 'mEssI']

# %%
a=[1,2,3]
b=[23,21]
c=50
d=['Txt']
e='aa'


tupla=tuple([a,b,c,d,e])

b=2*a
b
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a[0]=4
b=[21]
c=12
d=['chocolate']
e='ff'

tupla
# Out:
# ([4, 2, 3], [23, 21], 50, ['Txt'], 'aa')

# %%
a[0]=4
b[0]=21
c=12
d[0]=['chocolate','casa']
e='ff'

tupla
# Out:
# ([4, 2, 3], [23, 21], 50, ['Txt'], 'aa')

# %%
v, w, x, y, z = tupla
[v,w,x,y,z]
# Out:
# [[4, 2, 3], [23, 21], 50, ['Txt'], 'aa']

# %%
50 in tupla
# Out:
# True

# %%
seq1=[1,2,3,4,5,6]
seq2=['a','b','c','d','e']
seq3=[True,False,False,True,False]

z=zip(seq1,seq2,seq3)

a1, a2, a3= zip(*z)

print(tuple(z))

print(a1, a2, a3)
# Out:
# ()
# (1, 2, 3, 4, 5) ('a', 'b', 'c', 'd', 'e') (True, False, False, True, False)

# %%
for counter, val in enumerate(range(10,20)):
    print(counter, val)
# Out:
# 0 10
# 1 11
# 2 12
# 3 13
# 4 14
# 5 15
# 6 16
# 7 17
# 8 18
# 9 19

# %%
for counter, val in enumerate(reversed(range(10,20))):
    print(counter, val, counter+val)
# Out:
# 0 19 19
# 1 18 19
# 2 17 19
# 3 16 19
# 4 15 19
# 5 14 19
# 6 13 19
# 7 12 19
# 8 11 19
# 9 10 19

# %%
for  val in sum(range(10,20)):
    print( val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-256-83f57992a53d> in <module>
# ----> 1 for  val in sum(range(10,20)):
#       2     print( val)
#
# TypeError: 'int' object is not iterable

# %%
diccionario={'a':1,'b':2}

# %%
diccionario.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
diccionario=diccionario+{'c':3}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-5aaed85a19e4> in <module>
# ----> 1 diccionario=diccionario+{'c':3}
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
valores=(1,2,3,4,5)
keys=('a','b','c','d','e')

diccionario2=dict(zip(keys,valores))

diccionario2
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
list(diccionario2.values())
# Out:
# [1, 2, 3, 4, 5]

# %%
list(diccionario2.keys())
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
diccionario['c']=3
diccionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
del(diccionario['b'])
diccionario
# Out:
# {'a': 1, 'c': 3}

# %%
'a' in diccionario.keys()
# Out:
# True

# %%
1 in diccionario.values()
# Out:
# True

# %%
diccionario
#diccionario.pop[3]
# Out:
# {'a': 1, 'c': 3}

# %% [markdown]
# # LOS SETS SON ESPECIALMENTE ÚTILES CUANDO QUEREMOS HACER OPERACIONES CON CONJUNTOS, TIPO UNIONES, INTERSECCIONES, DIFERENCIAS, ETC...

# %%
s1=set([1,2,3,4,5])
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2={3,4,5,6,7,8}
s2
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
type(s2)
# Out:
# set

# %%
#union
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#intersección
s1&s2
# Out:
# {3, 4, 5}

# %%
#diferencia
s1-s2
# Out:
# {1, 2}

# %%
#diferencia
s2-s1
# Out:
# {6, 7, 8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1==s2
# Out:
# False

# %%
s1.remove(1)
s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-300-05843d55a631> in <module>
# ----> 1 s1.remove(1)
#       2 s1
#
# KeyError: 1

# %%
s1.discard(1)

# %%
s1s2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-307-a45bf8bf1631> in <module>
# ----> 1 s1.s2
#
# AttributeError: 'set' object has no attribute 's2'
