# %% [markdown]
# # Introduction to Neural Networks and Deep Learning

# %% [markdown]
# ## What's the difference between Artificial Intelligence, Machine Learning and Deep Learning?
#
# **Artificial Intelligence** (AI) is a very old field of research. It started in the 1950s; at that time, the pioneers in AI were convinced that they could make machines think. The initial approach was attempting to model intellectual tasks, and program those tasks in computers. That is, in the beginning, AI was about people *hard-coding* problems that the machine tried to solve. A good example of an early AI program is computer chess. Early AI computer chess programs had **lots of rules pre-conceived by the program designers**. So although the term refers to "intelligence", these programs were not "intelligent", but just a sophisticated set of rules.
#
# * The term *neural network* was also born at that time. The initial idea was trying to mimic how a *neuron* works (or in fact, how it was thought a neuron worked when the term was coined) in the brain. As in the case of *Artificial Intelligence*, please do not be fooled by the terms. A *neural network* is just a way to compute approximation to functions. A powerful and useful way, true. But it is not any kind of "artificial brain", or anything like that.
#
# This approach is now obsolete. We now know that some tasks are so complex, that we will never be able to pre-design a system to have a good performance on those tasks. Take the example of the game of Go. Any program designed by humans to play Go was dull and could not compete against professional players. The game is so hard that is just impossible for us as humans to conceived a good Go computer player.
# * https://en.wikipedia.org/wiki/Go_(game)
#
# The modern approach to solve this kind of problems involves the use of data. This is what the *learning* part of *Deep Learning* (and *Machine Learning*) refers to. **Learning from data**. So, with this brief introduction, we can say that *Artificial Intelligence* is a broad concept that includes *Machine Learning*, that includes *Deep Learning*. *Artificial Intelligence* does not necessarily means learning from data, but Machine Learning does. And *Deep Learning* is just doing *Machine Learning* with neural networks.
#
# ![](imgs/01_ai_ml_dl.png)
#
# We will see during this course what *learning* means, and what is a *neural network*.
#
# In the case of the game of Go, all attempts to design a good Go computer player failed, until Google DeepMind created AlphaGo, a system that *learned* to play Go based on data from previous games. AlphaGo is an example that learning from data can provide computer systems that are superior to any system pre-conceived by humans.
# * Find out more about AlphaGo by watching this utterly interesting movie: https://www.alphagomovie.com/
#
# In this course, we will give our first steps on *Deep Learning* and *Neural Networks*, to start creating systems that perform complex tasks by learning from data. Instead of attempting to derive the rules by ourselves, those rules will be inferred by a neural network based on the data we provide:
#
# ![](imgs/02_rules_data.png)

# %% [markdown]
# # Deep Learning and Machine Learning: why is everyone now talking about Deep Learning?
#
# To create our system, we need data:
# * Input data points; e.g. images to recognize shapes inside the images.
# * Examples of expected output. The system will use these examples to learn from them. For the images above, we will need *labels* telling us what is in the image.
#
# The neural network will *learn* from this data. But in fact, what the network is doing is learning a *representation* of the data that makes the task much easier to solve.
#
# Let's see an example. We have the following input data (x,y coordinates for the points), and the labels of each item (the color of the point). We would like to obtain a model to separete the two classes of points:
#
# ![](imgs/03_points.png)
#
# How would you separate the points? In the current reference system, it can be a complex task. But if you change the reference system (*if you learn a new representation of the data*), the task becomes trivial:
#
# ![](imgs/04_representation.png)
#
# In Deep Learning, we learn **layers** of increasingly better representations. The **deep** in Deep Learning refers to the number of layers that we learn. Before Deep Learning, the models that we are going to see today were much shallower. The most typical form of the layer representations is **neural networks**. As we will see, **neural networks** are just chain of matrix operations -- arrays of 2 dimensions--, or more precisely, tensor operations, we will operate in dimensions higher than 2.
#
#
# * More about learning representations: https://www.bbvadata.com/not-deep-learning-learning-represent/

# %% [markdown]
# ## Neural Networks
#
# A neural network is just a stacked set of layers. Each layer is represented by a tensor, and it performs an affine transformation on each one of the layers.
# * A matrix is a 2D tensor
# * Affine transformation $\vec{y} = W\cdot\vec{x} + \vec{b}$, where $W$ is the weights tensor, $\vec{x}$ is the input data, $\vec{y}$ is the output data and $\vec{b}$ is called the bias
# * $W$ and $\vec{b}$ are model parameters that need to be found by training
#
# ![](imgs/05_nn.png)
#
# Note that this is a **linear operation**, therefore the result will be linear too. But the functions we want to learn are normally non-linear. How do we overcome this limiation? By using an **activation function**, that transforms the result from the linear operation. So, we actually do the following operation:
#
# $\vec{y} = f\left(W\cdot\vec{x} + \vec{b}\right)$
#
# There are several common activation functions, depending on the characteristics of the data and the kind of problem we want to solve. Here we will use the probably most often used activation function: **rectified linear unit**, or **relu** for friends:
#
# ![Relu plot](https://upload.wikimedia.org/wikipedia/commons/6/6c/Rectifier_and_softplus_functions.svg)
#
# (image extracted from https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Relu will add the non-linearity that we need to learn arbitrary functions.
#
# We can achieve the same with many other activation functions. See the documentation of Keras for details on the available activation functions:
#  - https://keras.io/activations/
#
#
# Each layer learns a new representation of the input data, and after several layers, the representation will make it straightforward to solve the task (e.g. assiging a digit to an image of a digit).
#
# Until very recently, any attempt to train a deep neural network would not provide good results. Recent progresses (e.g. advances in hardware, new activation functions) make it possible to train very deep network, and therefore, solve problems that were unfeasible not long ago.
#
# ### Training process
#
# The parameters of the network are initially randomly assigned. Then after each pass of the network, that is, after each *epoch*, the predictions of the network is compared against the true values, applying a *loss function*. This score is used to update the parameters of the network, with a process called **backpropagation**.
# * Backpropagation is a complex process that involves calculating the gradient of the parameters of the network. For more details see: https://en.wikipedia.org/wiki/Backpropagation
# * See also this excellent and visual explanation of how backpropagation works: https://google-developers.appspot.com/machine-learning/crash-course/backprop-scroll/
#
# The training process is just an optimization process, that is normally done using a gradient descent-based algorithm. The values of gradients are computed using the backpropagation algorithm. Each epoch will make the loss score to be lower, and the predictions to be better.
#
# ![](imgs/06_optim.png)
#
# In practice, we have to fine tune the number of epochs (and other parameters), until we obtain a result that is good enough for our purpose. In fact, if the number of epochs is too high, our model may **overfit** the training data. In that case, it will perform worsely when the model is exposed to data that it  has not seen previously.
# * Fine tuning the number of epochs, and other parameters (e.g. the number and shape of the layers) is known as **hyperparameters optimization**, or **hyperparameters tuning**
# * The parameters of the model are the $W$ and $b$ values of each layer, and those are determined by training.
#
# ## Hyperparameters tuning
#
# In summary, when we are trying to obtain a deep learning model, the process that we will follow is:
# * Decide on the architecture of the network (number of layers, type of each layer, size of each layer)
# * Decide on the activation functions on each layer
# * Decide on the parameters related to the optimization process (e.g. learning rate)
# * Decide on the loss function that we will use
# * Decide on the metrics that we will use to evaluate the performance of the model
# * Decide on the training parameters (number of epochs, batch size)
# * Decide on how to split the data between training, validation and test sets.
#
# We obtain feedback for those decisions with the results of the training applied to the validation set. We train once, change some of the hyperparameters, train again, decide if that's better, and we keep going until we have found a model that is satisfactory enough for our purposes.
#
# After that, we finally evaluate the model on the test set.

# %% [markdown]
# ## Our first neural network
#
# Let's start with an easy example. We are going to produce some synthetic data, and will try to predict the function that generates the data. We will add some noise, to make the problem more difficult.
#
# The function we are going to try to predict is
#
# $\displaystyle y = 3*x + 2$

# %%
# %pylab inline
plt.style.use('seaborn-talk')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_metric(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.show()

# %% [markdown]
# ### Preparar los datos

# %%
x_train = np.linspace(0, 100, 1000)
y_train = 3*x_train + 2

x_test = np.linspace(100.01, 110, 100)
y_test = 3*x_test + 2

# %%
plot(x_train, y_train, 'b')
plot(x_test, y_test, 'r')

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras import models
from keras import layers

# %%
m = models.Sequential()
capa_oculta = layers.Dense(units=64, input_shape=(1,))
m.add(capa_oculta)
salida = layers.Dense(units=1)
m.add(salida)
m.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
m = models.Sequential()
m.add(layers.Dense(units=128, input_shape=(1,), activation='relu'))
m.add(layers.Dense(units=64, activation='relu'))
m.add(layers.Dense(units=32, activation='relu'))
m.add(layers.Dense(units=16, activation='relu'))
m.add(layers.Dense(units=1, activation='relu'))

m.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               256
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
from keras import losses
from keras import metrics

# %%
m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
h = m.fit(x_train, y_train, batch_size=100, epochs=80, validation_split=0.2)

# %%
plot_metric(h, 'loss')

# %%
plot_metric(h, 'mean_absolute_error')

# %%
m.evaluate(x_test, y_test)
# Out:
# 100/100 [==============================] - 0s 249us/step
# [17.396879425048827, 4.169457092285156]

# %%
y_hat = m.predict(x_test)
plt.plot(x_train, y_train, 'r')
plt.plot(x_test, y_test, 'b')
plt.plot(x_test, y_hat, '--g')
plt.show()

# %%
def build(act=None):
  m = models.Sequential()
  m.add(layers.Dense(units=64, input_shape=(1,), activation=act))
  m.add(layers.Dense(units=16, activation=act))
  m.add(layers.Dense(units=8, activation=act))
  m.add(layers.Dense(units=1, activation=act))
  m.summary()
  m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
  return m

# %%
m = build(act='elu')
h = m.fit(x_train, y_train, batch_size=100, epochs=150, validation_split=0.2)
plot_metric(h, 'loss')
y_hat = m.predict(x_test)
plt.plot(x_train, y_train, 'r')
plt.plot(x_test, y_test, 'b')
plt.plot(x_test, y_hat, '--g')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# Train on 800 samples, validate on 200 samples
# Epoch 1/150
# 800/800 [==============================] - 0s 387us/step - loss: 19189.8230 - mean_absolute_error: 120.2238 - val_loss: 71652.1758 - val_mean_absolute_error: 267.1303
# Epoch 2/150
# 800/800 [==============================] - 0s 49us/step - loss: 18401.0081 - mean_absolute_error: 117.5887 - val_loss: 67227.6641 - val_mean_absolute_error: 258.7488
# Epoch 3/150
# 800/800 [==============================] - 0s 47us/step - loss: 16906.1403 - mean_absolute_error: 112.4992 - val_loss: 61435.4727 - val_mean_absolute_error: 247.3482
# Epoch 4/150
# 800/800 [==============================] - 0s 51us/step - loss: 15309.7367 - mean_absolute_error: 106.9070 - val_loss: 55412.7090 - val_mean_absolute_error: 234.9084
# Epoch 5/150
# 800/800 [==============================] - 0s 53us/step - loss: 13605.4238 - mean_absolute_error: 100.7033 - val_loss: 48765.5430 - val_mean_absolute_error: 220.3658
# Epoch 6/150
# 800/800 [==============================] - 0s 50us/step - loss: 11801.4531 - mean_absolute_error: 93.5369 - val_loss: 41882.5000 - val_mean_absolute_error: 204.2190
# Epoch 7/150
# 800/800 [==============================] - 0s 48us/step - loss: 9930.8652 - mean_absolute_error: 85.5718 - val_loss: 34828.2676 - val_mean_absolute_error: 186.2240
# Epoch 8/150
# 800/800 [==============================] - 0s 49us/step - loss: 8060.0237 - mean_absolute_error: 76.8556 - val_loss: 27785.6445 - val_mean_absolute_error: 166.3285
# Epoch 9/150
# 800/800 [==============================] - 0s 50us/step - loss: 6214.2079 - mean_absolute_error: 67.1529 - val_loss: 20956.5977 - val_mean_absolute_error: 144.4436
# Epoch 10/150
# 800/800 [==============================] - 0s 48us/step - loss: 4482.9241 - mean_absolute_error: 56.6597 - val_loss: 14668.8237 - val_mean_absolute_error: 120.8394
# Epoch 11/150
# 800/800 [==============================] - 0s 47us/step - loss: 2947.6071 - mean_absolute_error: 45.5196 - val_loss: 9246.1792 - val_mean_absolute_error: 95.9287
# Epoch 12/150
# 800/800 [==============================] - 0s 52us/step - loss: 1698.4996 - mean_absolute_error: 34.0056 - val_loss: 5024.8140 - val_mean_absolute_error: 70.7052
# Epoch 13/150
# 800/800 [==============================] - 0s 45us/step - loss: 799.9965 - mean_absolute_error: 22.9079 - val_loss: 2180.6053 - val_mean_absolute_error: 46.5611
# Epoch 14/150
# 800/800 [==============================] - 0s 64us/step - loss: 278.4194 - mean_absolute_error: 13.2001 - val_loss: 696.5409 - val_mean_absolute_error: 26.2918
# Epoch 15/150
# 800/800 [==============================] - 0s 50us/step - loss: 68.6480 - mean_absolute_error: 6.6867 - val_loss: 177.6769 - val_mean_absolute_error: 13.2467
# Epoch 16/150
# 800/800 [==============================] - 0s 45us/step - loss: 21.0927 - mean_absolute_error: 4.0194 - val_loss: 69.6967 - val_mean_absolute_error: 8.2704
# Epoch 17/150
# 800/800 [==============================] - 0s 48us/step - loss: 13.5469 - mean_absolute_error: 3.2237 - val_loss: 51.6006 - val_mean_absolute_error: 7.1142
# Epoch 18/150
# 800/800 [==============================] - 0s 46us/step - loss: 9.8226 - mean_absolute_error: 2.7422 - val_loss: 20.8944 - val_mean_absolute_error: 4.4970
# Epoch 19/150
# 800/800 [==============================] - 0s 45us/step - loss: 7.0750 - mean_absolute_error: 2.3102 - val_loss: 6.8997 - val_mean_absolute_error: 2.5350
# Epoch 20/150
# 800/800 [==============================] - 0s 64us/step - loss: 5.6668 - mean_absolute_error: 2.0864 - val_loss: 1.1237 - val_mean_absolute_error: 0.8968
# Epoch 21/150
# 800/800 [==============================] - 0s 56us/step - loss: 5.3218 - mean_absolute_error: 2.0097 - val_loss: 13.1589 - val_mean_absolute_error: 3.5660
# Epoch 22/150
# 800/800 [==============================] - 0s 53us/step - loss: 5.7559 - mean_absolute_error: 2.0352 - val_loss: 5.7845 - val_mean_absolute_error: 2.3251
# Epoch 23/150
# 800/800 [==============================] - 0s 45us/step - loss: 2.1919 - mean_absolute_error: 1.2413 - val_loss: 4.8299 - val_mean_absolute_error: 2.1697
# Epoch 24/150
# 800/800 [==============================] - 0s 44us/step - loss: 4.5896 - mean_absolute_error: 1.7657 - val_loss: 0.2608 - val_mean_absolute_error: 0.4317
# Epoch 25/150
# 800/800 [==============================] - 0s 46us/step - loss: 3.7347 - mean_absolute_error: 1.6276 - val_loss: 0.7339 - val_mean_absolute_error: 0.7401
# Epoch 26/150
# 800/800 [==============================] - 0s 53us/step - loss: 3.4948 - mean_absolute_error: 1.5192 - val_loss: 0.7136 - val_mean_absolute_error: 0.6966
# Epoch 27/150
# 800/800 [==============================] - 0s 53us/step - loss: 2.2749 - mean_absolute_error: 1.2290 - val_loss: 0.6132 - val_mean_absolute_error: 0.6650
# Epoch 28/150
# 800/800 [==============================] - 0s 63us/step - loss: 3.1781 - mean_absolute_error: 1.4406 - val_loss: 0.2256 - val_mean_absolute_error: 0.4062
# Epoch 29/150
# 800/800 [==============================] - 0s 51us/step - loss: 3.2740 - mean_absolute_error: 1.4678 - val_loss: 3.3182 - val_mean_absolute_error: 1.7374
# Epoch 30/150
# 800/800 [==============================] - 0s 48us/step - loss: 3.7636 - mean_absolute_error: 1.5052 - val_loss: 7.5702 - val_mean_absolute_error: 2.6792
# Epoch 31/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.5416 - mean_absolute_error: 0.9177 - val_loss: 46.4821 - val_mean_absolute_error: 6.7753
# Epoch 32/150
# 800/800 [==============================] - 0s 47us/step - loss: 3.3105 - mean_absolute_error: 1.5127 - val_loss: 33.0411 - val_mean_absolute_error: 5.7057
# Epoch 33/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.8169 - mean_absolute_error: 1.4146 - val_loss: 22.3154 - val_mean_absolute_error: 4.6771
# Epoch 34/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.7212 - mean_absolute_error: 1.4182 - val_loss: 34.2175 - val_mean_absolute_error: 5.8034
# Epoch 35/150
# 800/800 [==============================] - 0s 52us/step - loss: 2.9483 - mean_absolute_error: 1.4800 - val_loss: 26.1121 - val_mean_absolute_error: 5.0610
# Epoch 36/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.8203 - mean_absolute_error: 1.4415 - val_loss: 23.0871 - val_mean_absolute_error: 4.7557
# Epoch 37/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.5582 - mean_absolute_error: 1.3593 - val_loss: 21.6472 - val_mean_absolute_error: 4.6065
# Epoch 38/150
# 800/800 [==============================] - 0s 58us/step - loss: 3.1786 - mean_absolute_error: 1.5533 - val_loss: 21.1376 - val_mean_absolute_error: 4.5460
# Epoch 39/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.6036 - mean_absolute_error: 1.3686 - val_loss: 21.9638 - val_mean_absolute_error: 4.6375
# Epoch 40/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.9727 - mean_absolute_error: 1.4873 - val_loss: 18.0529 - val_mean_absolute_error: 4.1990
# Epoch 41/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.0508 - mean_absolute_error: 1.2164 - val_loss: 27.0447 - val_mean_absolute_error: 5.1555
# Epoch 42/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.4102 - mean_absolute_error: 1.2994 - val_loss: 21.0351 - val_mean_absolute_error: 4.5422
# Epoch 43/150
# 800/800 [==============================] - 0s 53us/step - loss: 2.8563 - mean_absolute_error: 1.4336 - val_loss: 16.3653 - val_mean_absolute_error: 3.9969
# Epoch 44/150
# 800/800 [==============================] - 0s 50us/step - loss: 2.8659 - mean_absolute_error: 1.4220 - val_loss: 33.9772 - val_mean_absolute_error: 5.7817
# Epoch 45/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.3754 - mean_absolute_error: 1.2604 - val_loss: 12.5490 - val_mean_absolute_error: 3.4962
# Epoch 46/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.4212 - mean_absolute_error: 1.3167 - val_loss: 16.8332 - val_mean_absolute_error: 4.0541
# Epoch 47/150
# 800/800 [==============================] - 0s 52us/step - loss: 2.5214 - mean_absolute_error: 1.3465 - val_loss: 26.8367 - val_mean_absolute_error: 5.1344
# Epoch 48/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.8260 - mean_absolute_error: 1.1086 - val_loss: 22.8639 - val_mean_absolute_error: 4.7402
# Epoch 49/150
# 800/800 [==============================] - 0s 45us/step - loss: 2.7042 - mean_absolute_error: 1.2814 - val_loss: 10.0635 - val_mean_absolute_error: 3.1233
# Epoch 50/150
# 800/800 [==============================] - 0s 52us/step - loss: 3.5105 - mean_absolute_error: 1.4696 - val_loss: 16.1543 - val_mean_absolute_error: 3.9703
# Epoch 51/150
# 800/800 [==============================] - 0s 44us/step - loss: 1.0129 - mean_absolute_error: 0.7685 - val_loss: 23.9506 - val_mean_absolute_error: 4.8546
# Epoch 52/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.9664 - mean_absolute_error: 1.3526 - val_loss: 9.0797 - val_mean_absolute_error: 2.9661
# Epoch 53/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.7005 - mean_absolute_error: 1.3547 - val_loss: 27.1298 - val_mean_absolute_error: 5.1642
# Epoch 54/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.0167 - mean_absolute_error: 1.1810 - val_loss: 26.3545 - val_mean_absolute_error: 5.0957
# Epoch 55/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.5728 - mean_absolute_error: 1.3919 - val_loss: 21.3260 - val_mean_absolute_error: 4.5772
# Epoch 56/150
# 800/800 [==============================] - 0s 61us/step - loss: 1.9822 - mean_absolute_error: 1.2167 - val_loss: 21.4917 - val_mean_absolute_error: 4.5953
# Epoch 57/150
# 800/800 [==============================] - 0s 61us/step - loss: 2.5962 - mean_absolute_error: 1.3991 - val_loss: 23.7760 - val_mean_absolute_error: 4.8339
# Epoch 58/150
# 800/800 [==============================] - 0s 60us/step - loss: 2.0829 - mean_absolute_error: 1.1927 - val_loss: 12.7330 - val_mean_absolute_error: 3.5273
# Epoch 59/150
# 800/800 [==============================] - 0s 58us/step - loss: 2.8399 - mean_absolute_error: 1.4540 - val_loss: 14.4459 - val_mean_absolute_error: 3.7562
# Epoch 60/150
# 800/800 [==============================] - 0s 63us/step - loss: 2.0516 - mean_absolute_error: 1.2205 - val_loss: 18.2726 - val_mean_absolute_error: 4.2353
# Epoch 61/150
# 800/800 [==============================] - 0s 69us/step - loss: 2.2095 - mean_absolute_error: 1.2887 - val_loss: 21.5204 - val_mean_absolute_error: 4.5979
# Epoch 62/150
# 800/800 [==============================] - 0s 56us/step - loss: 1.8330 - mean_absolute_error: 1.1209 - val_loss: 35.5816 - val_mean_absolute_error: 5.9262
# Epoch 63/150
# 800/800 [==============================] - 0s 57us/step - loss: 2.6590 - mean_absolute_error: 1.2699 - val_loss: 9.6539 - val_mean_absolute_error: 3.0669
# Epoch 64/150
# 800/800 [==============================] - 0s 57us/step - loss: 2.4838 - mean_absolute_error: 1.3468 - val_loss: 22.9298 - val_mean_absolute_error: 4.7487
# Epoch 65/150
# 800/800 [==============================] - 0s 63us/step - loss: 1.2216 - mean_absolute_error: 0.8937 - val_loss: 18.8492 - val_mean_absolute_error: 4.3062
# Epoch 66/150
# 800/800 [==============================] - 0s 60us/step - loss: 2.9002 - mean_absolute_error: 1.3377 - val_loss: 7.0212 - val_mean_absolute_error: 2.6039
# Epoch 67/150
# 800/800 [==============================] - 0s 58us/step - loss: 1.8569 - mean_absolute_error: 0.8806 - val_loss: 29.4844 - val_mean_absolute_error: 5.3914
# Epoch 68/150
# 800/800 [==============================] - 0s 56us/step - loss: 1.7923 - mean_absolute_error: 1.0161 - val_loss: 4.9473 - val_mean_absolute_error: 2.1767
# Epoch 69/150
# 800/800 [==============================] - 0s 51us/step - loss: 2.4907 - mean_absolute_error: 1.2497 - val_loss: 30.2198 - val_mean_absolute_error: 5.4567
# Epoch 70/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.5434 - mean_absolute_error: 0.9181 - val_loss: 6.4817 - val_mean_absolute_error: 2.5013
# Epoch 71/150
# 800/800 [==============================] - 0s 46us/step - loss: 3.0107 - mean_absolute_error: 1.2940 - val_loss: 17.3313 - val_mean_absolute_error: 4.1214
# Epoch 72/150
# 800/800 [==============================] - 0s 44us/step - loss: 0.6725 - mean_absolute_error: 0.6289 - val_loss: 23.4107 - val_mean_absolute_error: 4.8040
# Epoch 73/150
# 800/800 [==============================] - 0s 53us/step - loss: 2.9042 - mean_absolute_error: 1.4317 - val_loss: 12.1420 - val_mean_absolute_error: 3.4445
# Epoch 74/150
# 800/800 [==============================] - 0s 60us/step - loss: 2.0467 - mean_absolute_error: 1.2324 - val_loss: 14.6555 - val_mean_absolute_error: 3.7893
# Epoch 75/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.7902 - mean_absolute_error: 1.1438 - val_loss: 13.1803 - val_mean_absolute_error: 3.5907
# Epoch 76/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.4769 - mean_absolute_error: 1.3554 - val_loss: 17.0050 - val_mean_absolute_error: 4.0840
# Epoch 77/150
# 800/800 [==============================] - 0s 48us/step - loss: 1.7695 - mean_absolute_error: 1.1390 - val_loss: 12.0039 - val_mean_absolute_error: 3.4254
# Epoch 78/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.4046 - mean_absolute_error: 1.3183 - val_loss: 14.9363 - val_mean_absolute_error: 3.8250
# Epoch 79/150
# 800/800 [==============================] - 0s 59us/step - loss: 1.7204 - mean_absolute_error: 1.0542 - val_loss: 27.1837 - val_mean_absolute_error: 5.1768
# Epoch 80/150
# 800/800 [==============================] - 0s 47us/step - loss: 1.8173 - mean_absolute_error: 1.1138 - val_loss: 22.2520 - val_mean_absolute_error: 4.6828
# Epoch 81/150
# 800/800 [==============================] - 0s 50us/step - loss: 2.2899 - mean_absolute_error: 1.2697 - val_loss: 10.2359 - val_mean_absolute_error: 3.1606
# Epoch 82/150
# 800/800 [==============================] - 0s 51us/step - loss: 2.2483 - mean_absolute_error: 1.2062 - val_loss: 21.7549 - val_mean_absolute_error: 4.6268
# Epoch 83/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.4858 - mean_absolute_error: 1.0356 - val_loss: 13.5453 - val_mean_absolute_error: 3.6427
# Epoch 84/150
# 800/800 [==============================] - 0s 62us/step - loss: 2.5020 - mean_absolute_error: 1.3509 - val_loss: 14.9635 - val_mean_absolute_error: 3.8307
# Epoch 85/150
# 800/800 [==============================] - 0s 56us/step - loss: 1.4431 - mean_absolute_error: 0.9914 - val_loss: 25.9836 - val_mean_absolute_error: 5.0628
# Epoch 86/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.5591 - mean_absolute_error: 1.3885 - val_loss: 13.2895 - val_mean_absolute_error: 3.6091
# Epoch 87/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.9325 - mean_absolute_error: 1.1979 - val_loss: 13.5592 - val_mean_absolute_error: 3.6470
# Epoch 88/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.7895 - mean_absolute_error: 1.1267 - val_loss: 23.8529 - val_mean_absolute_error: 4.8494
# Epoch 89/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.7778 - mean_absolute_error: 1.1168 - val_loss: 13.1220 - val_mean_absolute_error: 3.5869
# Epoch 90/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.3793 - mean_absolute_error: 1.3121 - val_loss: 33.3388 - val_mean_absolute_error: 5.7393
# Epoch 91/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.4325 - mean_absolute_error: 0.9512 - val_loss: 17.5165 - val_mean_absolute_error: 4.1521
# Epoch 92/150
# 800/800 [==============================] - 0s 50us/step - loss: 2.1076 - mean_absolute_error: 1.1810 - val_loss: 9.8276 - val_mean_absolute_error: 3.0990
# Epoch 93/150
# 800/800 [==============================] - 0s 62us/step - loss: 2.0633 - mean_absolute_error: 1.1980 - val_loss: 23.6940 - val_mean_absolute_error: 4.8329
# Epoch 94/150
# 800/800 [==============================] - 0s 50us/step - loss: 2.0502 - mean_absolute_error: 1.2339 - val_loss: 17.9698 - val_mean_absolute_error: 4.2057
# Epoch 95/150
# 800/800 [==============================] - 0s 55us/step - loss: 1.7771 - mean_absolute_error: 1.1190 - val_loss: 8.1201 - val_mean_absolute_error: 2.8134
# Epoch 96/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.2239 - mean_absolute_error: 1.2110 - val_loss: 14.7633 - val_mean_absolute_error: 3.8072
# Epoch 97/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.5536 - mean_absolute_error: 1.0176 - val_loss: 28.3156 - val_mean_absolute_error: 5.2891
# Epoch 98/150
# 800/800 [==============================] - 0s 47us/step - loss: 1.9925 - mean_absolute_error: 1.1159 - val_loss: 6.4296 - val_mean_absolute_error: 2.4991
# Epoch 99/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.6569 - mean_absolute_error: 1.2648 - val_loss: 22.5783 - val_mean_absolute_error: 4.7179
# Epoch 100/150
# 800/800 [==============================] - 0s 49us/step - loss: 0.9679 - mean_absolute_error: 0.7301 - val_loss: 6.5680 - val_mean_absolute_error: 2.5286
# Epoch 101/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.2912 - mean_absolute_error: 1.2721 - val_loss: 16.1926 - val_mean_absolute_error: 3.9906
# Epoch 102/150
# 800/800 [==============================] - 0s 53us/step - loss: 1.9737 - mean_absolute_error: 1.2124 - val_loss: 10.2243 - val_mean_absolute_error: 3.1651
# Epoch 103/150
# 800/800 [==============================] - 0s 53us/step - loss: 1.8272 - mean_absolute_error: 1.1725 - val_loss: 12.1758 - val_mean_absolute_error: 3.4568
# Epoch 104/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.7822 - mean_absolute_error: 1.1536 - val_loss: 11.8398 - val_mean_absolute_error: 3.4077
# Epoch 105/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.2186 - mean_absolute_error: 1.2609 - val_loss: 18.4545 - val_mean_absolute_error: 4.2630
# Epoch 106/150
# 800/800 [==============================] - 0s 45us/step - loss: 1.3379 - mean_absolute_error: 0.9585 - val_loss: 17.7483 - val_mean_absolute_error: 4.1826
# Epoch 107/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.5904 - mean_absolute_error: 1.3827 - val_loss: 10.6324 - val_mean_absolute_error: 3.2283
# Epoch 108/150
# 800/800 [==============================] - 0s 45us/step - loss: 1.3007 - mean_absolute_error: 0.9791 - val_loss: 17.4037 - val_mean_absolute_error: 4.1406
# Epoch 109/150
# 800/800 [==============================] - 0s 63us/step - loss: 2.2960 - mean_absolute_error: 1.2943 - val_loss: 18.8544 - val_mean_absolute_error: 4.3101
# Epoch 110/150
# 800/800 [==============================] - 0s 48us/step - loss: 1.1499 - mean_absolute_error: 0.8824 - val_loss: 15.0582 - val_mean_absolute_error: 3.8504
# Epoch 111/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.4077 - mean_absolute_error: 1.3437 - val_loss: 13.6198 - val_mean_absolute_error: 3.6592
# Epoch 112/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.0787 - mean_absolute_error: 1.2235 - val_loss: 12.5571 - val_mean_absolute_error: 3.5127
# Epoch 113/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.2341 - mean_absolute_error: 0.9535 - val_loss: 14.5887 - val_mean_absolute_error: 3.7882
# Epoch 114/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.2495 - mean_absolute_error: 1.2996 - val_loss: 16.4823 - val_mean_absolute_error: 4.0295
# Epoch 115/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.5090 - mean_absolute_error: 1.0226 - val_loss: 11.1887 - val_mean_absolute_error: 3.3151
# Epoch 116/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.1097 - mean_absolute_error: 1.2529 - val_loss: 22.8262 - val_mean_absolute_error: 4.7472
# Epoch 117/150
# 800/800 [==============================] - 0s 52us/step - loss: 1.6455 - mean_absolute_error: 1.0898 - val_loss: 10.7740 - val_mean_absolute_error: 3.2524
# Epoch 118/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.7034 - mean_absolute_error: 1.1236 - val_loss: 14.1926 - val_mean_absolute_error: 3.7375
# Epoch 119/150
# 800/800 [==============================] - 0s 56us/step - loss: 2.1056 - mean_absolute_error: 1.2633 - val_loss: 16.9331 - val_mean_absolute_error: 4.0857
# Epoch 120/150
# 800/800 [==============================] - 0s 45us/step - loss: 1.5972 - mean_absolute_error: 1.0457 - val_loss: 12.0660 - val_mean_absolute_error: 3.4454
# Epoch 121/150
# 800/800 [==============================] - 0s 56us/step - loss: 2.1217 - mean_absolute_error: 1.2460 - val_loss: 15.2550 - val_mean_absolute_error: 3.8777
# Epoch 122/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.8180 - mean_absolute_error: 1.1551 - val_loss: 11.7273 - val_mean_absolute_error: 3.3964
# Epoch 123/150
# 800/800 [==============================] - 0s 52us/step - loss: 1.6841 - mean_absolute_error: 1.1148 - val_loss: 10.4682 - val_mean_absolute_error: 3.2064
# Epoch 124/150
# 800/800 [==============================] - 0s 55us/step - loss: 1.7418 - mean_absolute_error: 1.1011 - val_loss: 29.2374 - val_mean_absolute_error: 5.3777
# Epoch 125/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.1236 - mean_absolute_error: 1.1410 - val_loss: 4.5215 - val_mean_absolute_error: 2.0964
# Epoch 126/150
# 800/800 [==============================] - 0s 50us/step - loss: 1.6230 - mean_absolute_error: 0.9744 - val_loss: 33.6575 - val_mean_absolute_error: 5.7721
# Epoch 127/150
# 800/800 [==============================] - 0s 52us/step - loss: 1.6873 - mean_absolute_error: 0.9828 - val_loss: 4.2303 - val_mean_absolute_error: 2.0262
# Epoch 128/150
# 800/800 [==============================] - 0s 49us/step - loss: 1.7110 - mean_absolute_error: 1.0573 - val_loss: 19.0531 - val_mean_absolute_error: 4.3363
# Epoch 129/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.1794 - mean_absolute_error: 1.2710 - val_loss: 11.1313 - val_mean_absolute_error: 3.3087
# Epoch 130/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.2853 - mean_absolute_error: 0.9741 - val_loss: 15.2394 - val_mean_absolute_error: 3.8775
# Epoch 131/150
# 800/800 [==============================] - 0s 48us/step - loss: 2.4101 - mean_absolute_error: 1.3530 - val_loss: 16.1487 - val_mean_absolute_error: 3.9910
# Epoch 132/150
# 800/800 [==============================] - 0s 47us/step - loss: 0.9641 - mean_absolute_error: 0.8194 - val_loss: 7.9269 - val_mean_absolute_error: 2.7882
# Epoch 133/150
# 800/800 [==============================] - 0s 54us/step - loss: 2.2944 - mean_absolute_error: 1.2482 - val_loss: 7.5439 - val_mean_absolute_error: 2.7190
# Epoch 134/150
# 800/800 [==============================] - 0s 57us/step - loss: 1.8925 - mean_absolute_error: 1.0913 - val_loss: 13.0513 - val_mean_absolute_error: 3.5860
# Epoch 135/150
# 800/800 [==============================] - 0s 50us/step - loss: 1.4402 - mean_absolute_error: 1.0025 - val_loss: 21.3458 - val_mean_absolute_error: 4.5936
# Epoch 136/150
# 800/800 [==============================] - 0s 56us/step - loss: 1.5538 - mean_absolute_error: 0.9683 - val_loss: 6.8802 - val_mean_absolute_error: 2.5967
# Epoch 137/150
# 800/800 [==============================] - 0s 49us/step - loss: 2.4665 - mean_absolute_error: 1.2783 - val_loss: 11.1540 - val_mean_absolute_error: 3.3131
# Epoch 138/150
# 800/800 [==============================] - 0s 47us/step - loss: 0.9700 - mean_absolute_error: 0.8366 - val_loss: 12.7296 - val_mean_absolute_error: 3.5426
# Epoch 139/150
# 800/800 [==============================] - 0s 50us/step - loss: 1.9967 - mean_absolute_error: 1.2203 - val_loss: 20.7240 - val_mean_absolute_error: 4.5264
# Epoch 140/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.6178 - mean_absolute_error: 1.0471 - val_loss: 12.2600 - val_mean_absolute_error: 3.4765
# Epoch 141/150
# 800/800 [==============================] - 0s 50us/step - loss: 2.1188 - mean_absolute_error: 1.2697 - val_loss: 15.4032 - val_mean_absolute_error: 3.8994
# Epoch 142/150
# 800/800 [==============================] - 0s 50us/step - loss: 1.6179 - mean_absolute_error: 1.0889 - val_loss: 7.0040 - val_mean_absolute_error: 2.6214
# Epoch 143/150
# 800/800 [==============================] - 0s 47us/step - loss: 1.7399 - mean_absolute_error: 1.1262 - val_loss: 8.4855 - val_mean_absolute_error: 2.8878
# Epoch 144/150
# 800/800 [==============================] - 0s 50us/step - loss: 1.7092 - mean_absolute_error: 1.1035 - val_loss: 11.3854 - val_mean_absolute_error: 3.3488
# Epoch 145/150
# 800/800 [==============================] - 0s 46us/step - loss: 1.8035 - mean_absolute_error: 1.1450 - val_loss: 14.4061 - val_mean_absolute_error: 3.7708
# Epoch 146/150
# 800/800 [==============================] - 0s 47us/step - loss: 1.4650 - mean_absolute_error: 1.0105 - val_loss: 6.1279 - val_mean_absolute_error: 2.4503
# Epoch 147/150
# 800/800 [==============================] - 0s 47us/step - loss: 2.4441 - mean_absolute_error: 1.2362 - val_loss: 10.7944 - val_mean_absolute_error: 3.2611
# Epoch 148/150
# 800/800 [==============================] - 0s 50us/step - loss: 0.4152 - mean_absolute_error: 0.4778 - val_loss: 15.4045 - val_mean_absolute_error: 3.9019
# Epoch 149/150
# 800/800 [==============================] - 0s 46us/step - loss: 2.8657 - mean_absolute_error: 1.4061 - val_loss: 5.5962 - val_mean_absolute_error: 2.3415
# Epoch 150/150
# 800/800 [==============================] - 0s 51us/step - loss: 1.3387 - mean_absolute_error: 0.9351 - val_loss: 22.6185 - val_mean_absolute_error: 4.7317

# %% [markdown]
# ### Now another more complex function
#
# Let's try to fit a parabollic function
#
# $\displaystyle y = -2x^2 + x + 1$

# %%
x_train=np.linspace(1,2,1000)
y_train= x_train**3/10.-x_train**(1/2)+x_train/2

xt_min=x_train.min()
xt_max=x_train.max()
yt_min=y_train.min()
yt_max=y_train.max()

x_train_s=(x_train-xt_min)/(xt_max-xt_min)
y_train_s=(y_train-yt_min)/(yt_max-yt_min)

x_test=np.linspace(2,2.5,200)
y_test=x_test**3/10.-x_test**(1/2)+x_test/2

x_test_s=(x_test-xt_min)/(xt_max-xt_min)
y_test_s=(y_test-yt_min)/(yt_max-yt_min)

plot(x_train_s, y_train_s)
plot(x_test_s, y_test_s, 'r')
plt.plot
# Out:
# <function matplotlib.pyplot.plot>

# %%
def build(act=None):
  m = models.Sequential()
  m.add(layers.Dense(units=8, input_shape=(1,), activation=act))
  m.add(layers.Dense(units=4, activation=act))
  m.add(layers.Dense(units=2, activation=act))
  m.add(layers.Dense(units=1, activation=act))
  m.summary()
  m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
  return m

# %%
m = build(act='elu')
h = m.fit(x_train_s, y_train_s, batch_size=100, epochs=60, validation_split=0.2)
# plot_metric(h, 'loss')
y_hat = m.predict(x_test_s)
plt.plot(x_train_s, y_train_s, 'r')
plt.plot(x_test_s, y_test_s, 'b')
plt.plot(x_test_s, y_hat/100, '--g')
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 8)                 16
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 800 samples, validate on 200 samples
# Epoch 1/60
# 800/800 [==============================] - 5s 6ms/step - loss: 0.2017 - mean_absolute_error: 0.3650 - val_loss: 0.9529 - val_mean_absolute_error: 0.9712
# Epoch 2/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.1341 - mean_absolute_error: 0.2880 - val_loss: 0.7563 - val_mean_absolute_error: 0.8642
# Epoch 3/60
# 800/800 [==============================] - 0s 49us/step - loss: 0.0906 - mean_absolute_error: 0.2364 - val_loss: 0.5893 - val_mean_absolute_error: 0.7618
# Epoch 4/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0641 - mean_absolute_error: 0.2037 - val_loss: 0.4621 - val_mean_absolute_error: 0.6735
# Epoch 5/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.0493 - mean_absolute_error: 0.1852 - val_loss: 0.3707 - val_mean_absolute_error: 0.6022
# Epoch 6/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0413 - mean_absolute_error: 0.1741 - val_loss: 0.3079 - val_mean_absolute_error: 0.5480
# Epoch 7/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.0365 - mean_absolute_error: 0.1653 - val_loss: 0.2710 - val_mean_absolute_error: 0.5138
# Epoch 8/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.0320 - mean_absolute_error: 0.1553 - val_loss: 0.2379 - val_mean_absolute_error: 0.4810
# Epoch 9/60
# 800/800 [==============================] - 0s 54us/step - loss: 0.0274 - mean_absolute_error: 0.1444 - val_loss: 0.2171 - val_mean_absolute_error: 0.4593
# Epoch 10/60
# 800/800 [==============================] - 0s 46us/step - loss: 0.0228 - mean_absolute_error: 0.1309 - val_loss: 0.1759 - val_mean_absolute_error: 0.4127
# Epoch 11/60
# 800/800 [==============================] - 0s 49us/step - loss: 0.0184 - mean_absolute_error: 0.1183 - val_loss: 0.1581 - val_mean_absolute_error: 0.3913
# Epoch 12/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0142 - mean_absolute_error: 0.1034 - val_loss: 0.1200 - val_mean_absolute_error: 0.3399
# Epoch 13/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0107 - mean_absolute_error: 0.0905 - val_loss: 0.1071 - val_mean_absolute_error: 0.3210
# Epoch 14/60
# 800/800 [==============================] - 0s 57us/step - loss: 0.0077 - mean_absolute_error: 0.0760 - val_loss: 0.0873 - val_mean_absolute_error: 0.2893
# Epoch 15/60
# 800/800 [==============================] - 0s 56us/step - loss: 0.0053 - mean_absolute_error: 0.0627 - val_loss: 0.0742 - val_mean_absolute_error: 0.2666
# Epoch 16/60
# 800/800 [==============================] - 0s 53us/step - loss: 0.0035 - mean_absolute_error: 0.0494 - val_loss: 0.0528 - val_mean_absolute_error: 0.2236
# Epoch 17/60
# 800/800 [==============================] - 0s 53us/step - loss: 0.0022 - mean_absolute_error: 0.0384 - val_loss: 0.0365 - val_mean_absolute_error: 0.1848
# Epoch 18/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0015 - mean_absolute_error: 0.0323 - val_loss: 0.0274 - val_mean_absolute_error: 0.1588
# Epoch 19/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0012 - mean_absolute_error: 0.0296 - val_loss: 0.0312 - val_mean_absolute_error: 0.1709
# Epoch 20/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0011 - mean_absolute_error: 0.0282 - val_loss: 0.0236 - val_mean_absolute_error: 0.1473
# Epoch 21/60
# 800/800 [==============================] - 0s 53us/step - loss: 0.0012 - mean_absolute_error: 0.0291 - val_loss: 0.0229 - val_mean_absolute_error: 0.1452
# Epoch 22/60
# 800/800 [==============================] - 0s 47us/step - loss: 0.0011 - mean_absolute_error: 0.0281 - val_loss: 0.0238 - val_mean_absolute_error: 0.1480
# Epoch 23/60
# 800/800 [==============================] - 0s 62us/step - loss: 0.0011 - mean_absolute_error: 0.0281 - val_loss: 0.0185 - val_mean_absolute_error: 0.1292
# Epoch 24/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0011 - mean_absolute_error: 0.0284 - val_loss: 0.0203 - val_mean_absolute_error: 0.1360
# Epoch 25/60
# 800/800 [==============================] - 0s 56us/step - loss: 0.0011 - mean_absolute_error: 0.0278 - val_loss: 0.0187 - val_mean_absolute_error: 0.1300
# Epoch 26/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0011 - mean_absolute_error: 0.0282 - val_loss: 0.0179 - val_mean_absolute_error: 0.1270
# Epoch 27/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0011 - mean_absolute_error: 0.0285 - val_loss: 0.0228 - val_mean_absolute_error: 0.1448
# Epoch 28/60
# 800/800 [==============================] - 0s 49us/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0189 - val_mean_absolute_error: 0.1308
# Epoch 29/60
# 800/800 [==============================] - 0s 51us/step - loss: 0.0010 - mean_absolute_error: 0.0277 - val_loss: 0.0237 - val_mean_absolute_error: 0.1481
# Epoch 30/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.0011 - mean_absolute_error: 0.0283 - val_loss: 0.0239 - val_mean_absolute_error: 0.1487
# Epoch 31/60
# 800/800 [==============================] - 0s 50us/step - loss: 0.0011 - mean_absolute_error: 0.0280 - val_loss: 0.0207 - val_mean_absolute_error: 0.1375
# Epoch 32/60
# 800/800 [==============================] - 0s 49us/step - loss: 0.0010 - mean_absolute_error: 0.0274 - val_loss: 0.0207 - val_mean_absolute_error: 0.1375
# Epoch 33/60
# 800/800 [==============================] - 0s 49us/step - loss: 9.9964e-04 - mean_absolute_error: 0.0273 - val_loss: 0.0254 - val_mean_absolute_error: 0.1536
# Epoch 34/60
# 800/800 [==============================] - 0s 53us/step - loss: 0.0011 - mean_absolute_error: 0.0280 - val_loss: 0.0243 - val_mean_absolute_error: 0.1500
# Epoch 35/60
# 800/800 [==============================] - 0s 56us/step - loss: 0.0010 - mean_absolute_error: 0.0269 - val_loss: 0.0182 - val_mean_absolute_error: 0.1283
# Epoch 36/60
# 800/800 [==============================] - 0s 47us/step - loss: 9.8885e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0239 - val_mean_absolute_error: 0.1488
# Epoch 37/60
# 800/800 [==============================] - 0s 48us/step - loss: 0.0011 - mean_absolute_error: 0.0273 - val_loss: 0.0177 - val_mean_absolute_error: 0.1265
# Epoch 38/60
# 800/800 [==============================] - 0s 57us/step - loss: 9.9818e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0222 - val_mean_absolute_error: 0.1431
# Epoch 39/60
# 800/800 [==============================] - 0s 46us/step - loss: 9.9013e-04 - mean_absolute_error: 0.0272 - val_loss: 0.0290 - val_mean_absolute_error: 0.1649
# Epoch 40/60
# 800/800 [==============================] - 0s 53us/step - loss: 0.0010 - mean_absolute_error: 0.0271 - val_loss: 0.0204 - val_mean_absolute_error: 0.1367
# Epoch 41/60
# 800/800 [==============================] - 0s 51us/step - loss: 9.9785e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0232 - val_mean_absolute_error: 0.1464
# Epoch 42/60
# 800/800 [==============================] - 0s 50us/step - loss: 9.6371e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0254 - val_mean_absolute_error: 0.1537
# Epoch 43/60
# 800/800 [==============================] - 0s 52us/step - loss: 9.7811e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0189 - val_mean_absolute_error: 0.1314
# Epoch 44/60
# 800/800 [==============================] - 0s 46us/step - loss: 9.6374e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0269 - val_mean_absolute_error: 0.1587
# Epoch 45/60
# 800/800 [==============================] - 0s 51us/step - loss: 9.7371e-04 - mean_absolute_error: 0.0262 - val_loss: 0.0197 - val_mean_absolute_error: 0.1344
# Epoch 46/60
# 800/800 [==============================] - 0s 54us/step - loss: 9.9860e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0171 - val_mean_absolute_error: 0.1242
# Epoch 47/60
# 800/800 [==============================] - 0s 48us/step - loss: 9.3423e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0219 - val_mean_absolute_error: 0.1420
# Epoch 48/60
# 800/800 [==============================] - 0s 48us/step - loss: 0.0011 - mean_absolute_error: 0.0274 - val_loss: 0.0190 - val_mean_absolute_error: 0.1317
# Epoch 49/60
# 800/800 [==============================] - 0s 49us/step - loss: 9.1595e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0174 - val_mean_absolute_error: 0.1258
# Epoch 50/60
# 800/800 [==============================] - 0s 50us/step - loss: 9.9564e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0204 - val_mean_absolute_error: 0.1368
# Epoch 51/60
# 800/800 [==============================] - 0s 48us/step - loss: 9.3097e-04 - mean_absolute_error: 0.0262 - val_loss: 0.0223 - val_mean_absolute_error: 0.1437
# Epoch 52/60
# 800/800 [==============================] - 0s 52us/step - loss: 9.1809e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0234 - val_mean_absolute_error: 0.1475
# Epoch 53/60
# 800/800 [==============================] - 0s 48us/step - loss: 9.3930e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0186 - val_mean_absolute_error: 0.1301
# Epoch 54/60
# 800/800 [==============================] - 0s 49us/step - loss: 9.7230e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0221 - val_mean_absolute_error: 0.1431
# Epoch 55/60
# 800/800 [==============================] - 0s 49us/step - loss: 9.4272e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0203 - val_mean_absolute_error: 0.1367
# Epoch 56/60
# 800/800 [==============================] - 0s 58us/step - loss: 9.3727e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0171 - val_mean_absolute_error: 0.1247
# Epoch 57/60
# 800/800 [==============================] - 0s 50us/step - loss: 9.4052e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0180 - val_mean_absolute_error: 0.1282
# Epoch 58/60
# 800/800 [==============================] - 0s 47us/step - loss: 9.0357e-04 - mean_absolute_error: 0.0258 - val_loss: 0.0205 - val_mean_absolute_error: 0.1374
# Epoch 59/60
# 800/800 [==============================] - 0s 50us/step - loss: 9.3107e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0223 - val_mean_absolute_error: 0.1439
# Epoch 60/60
# 800/800 [==============================] - 0s 51us/step - loss: 8.9387e-04 - mean_absolute_error: 0.0252 - val_loss: 0.0167 - val_mean_absolute_error: 0.1229

# %% [markdown]
# ### And now even a more complex one
#
# Let's try to predict now this function:
#
# $\displaystyle y = \cos(x)$
